# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '@KaipullaVadiveluOffl Selfie (2022) Tamil HQ HDRip - 25 - Shortcut.lnk',
#  '@Tentkotta4k Saani Kaayidham (2022) Tamil HQ HDRip - 40 - Shortcut.lnk',
#  'asdf',
#  'desktop.ini',
#  'Exercise',
#  'invoices.CSV',
#  'jdk-8u311-windows-x64.exe',
#  'jeevan.csv',
#  'Microsoft Edge.lnk',
#  'sparkinstall.docx',
#  'Spotify.lnk',
#  'Telegram.lnk',
#  'Test',
#  'Test.ipynb',
#  'Test_Cases.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Visual Studio Code.lnk']

# %%
import os
import pymysql
import pandas as pd

# %%
def createtable(tablename,filepath,cursor):
        #connection = pymysql.connect(host='127.0.0.1',user='root',password='1234')
        #cursor = connection.cursor()
        
        df = pd.read_csv(filepath)
        sql = 'create table '+ tablename  + '('
        for columns in df.columns:
            if  columns.endswith('Date'):
                sql = sql + columns + " nvarchar(255),"
            else:
                sql = sql + columns + " nvarchar(255),"
        sql = sql.rstrip(',') + ');'
                                #print(sql)
        
        #cursor.execute(f"DROP TABLE IF EXISTS {tablename}")
        cursor.execute(sql)

# %%
def insertdata(tablename,filepath):
    engine = create_engine('mysql+pymysql://root:1234@127.0.0.1/Test')
    df = pd.read_csv(filepath,index_col=0)
    df.to_sql(tablename,con=engine,if_exists='append',chunksize=1000)

# %%
import csv
import pymysql
import os
import pandas as pd
import pypyodbc
import mysql
from pathlib import Path
from sqlalchemy import create_engine
import re

def import_data():
    folder = input('')
    
    # Open a folder dialog to select the folder containing the data files
    rootdir = os.getcwd() + '\\' + folder
    if folder.islower() or any(c.isupper() for c in folder) & len(folder) <=120:
        print('Main folder name is acceptable.')
        
        while not os.path.exists(rootdir): 
            print('Directory does not exist')
            rootdir = input('Please enter a valid directory: ')
    else:
        if bool(re.search(r'[^A-Za-z0-9]')) == True:
            folder = os.rename(folder,folder.replace('^','_'))
    # Connect to the database
    connection = pymysql.connect(host='127.0.0.1',user='root',password='1234')
    cursor = connection.cursor()
    
  
    
    #creating the database
    if folder == 'select' or not folder.isalnum():
        print('Please rename the folder')
    else:
        subquery = 'create database ' + folder
        try:
            if cursor !=subquery:
                if os.path.exists(rootdir):
                    cursor.execute(subquery)

                else:
                    print('Main Folder not exists')

        except Exception:
            # Check if the database exists
            cursor.execute("SHOW DATABASES")
            databases = cursor.fetchall()
            database_exists = False
            for database in databases:
                if database[0] == folder:
                    database_exists = True
                    break

            if database_exists:

                print('Database is already exists')
                cursor.execute(f'DROP DATABASE {folder}')
                cursor.execute(f'CREATE DATABASE {folder}')
                connection.commit()
                #cursor.execute(subquery)

                #cursor.execute(f'USE {folder}')

            # Database exists, do something
       
    
    
    for subfolder in os.listdir(rootdir):
        try:
            subfolder_path = os.path.join(rootdir, subfolder)


                #check if subfolder containg special characters
                            # Check if there is a CSV file in the subfolder
            csv_file = None
            for file in os.listdir(subfolder_path):
                if file.lower().endswith('.csv'):
                    filepath = os.path.join(subfolder_path,file)
                    if os.stat(filepath).st_size == 0:
                        print('csv is empty')
                        #if file == 'Select' or not file.isalnum():
                            #print('Please rename the file')
                    else:
                        cursor.execute(f'USE {folder}')

                        createtable(subfolder,filepath,cursor)
                        insertdata(subfolder,filepath)

                        csv_file = os.path.join(subfolder_path, file)
                        break


                if not csv_file:
                                # No CSV file found in the subfolder
                    print(f"No data to import for {subfolder}. Please download the data files for {subfolder} and upload again")
                                #continue
                    pass
    
        except Exception as e:
            if subfolder == 'Select' or not subfolder.isalnum():
                print('Please rename the subfolder',e)


    
    # Iterate over the subfolders in the selected folder
    
    #else:
        #print('Directory does not exists, please enter a valid directory')
        
               
            
           
    # Save the changes and close the connection
    connection.commit()
    connection.close()

# Create the GUI
#root = tk.Tk()
#button = tk.Button(root, text='Import Data', command=import_data)
#button.pack()
#root.mainloop()

# %%
import_data()
# Out:
# file
# Main folder name is acceptable.
# Directory does not exist
# Please enter a valid directory: Exercise
# csv is empty
# Please rename the file
# No data to import for employees. Please download the data files for employees and upload again
# No data to import for management. Please download the data files for management and upload again
